# %%
EventLogs= spark.read.format("delta").option("header","true").load("Files/EventLogs")

EventLogs.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("EventLogs")
# Out:
# StatementMeta(, 40398876-72af-4ebb-9841-109fc21ea796, 5, Finished, Available)

# %%
RLS= spark.read.format("delta").option("header","true").load("Files/RLS")

RLS.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("RLS")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 6, Finished, Available)

# %%
Workspace_Company_Map= spark.read.format("delta").option("header","true").load("Files/Workspace_Company_Map")

Workspace_Company_Map.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspace_Company_Map")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 7, Finished, Available)

# %%
Workspace_dashboards= spark.read.format("delta").option("header","true").load("Files/Workspace_dashboards")

Workspace_dashboards.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspace_dashboards")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 8, Finished, Available)

# %%
Workspace_dataflows= spark.read.format("delta").option("header","true").load("Files/Workspace_dataflows")

Workspace_dataflows.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspace_dataflows")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 9, Finished, Available)

# %%
Workspace_datasets= spark.read.format("delta").option("header","true").load("Files/Workspace_datasets")

Workspace_datasets.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspace_datasets")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 10, Finished, Available)

# %%
Workspace_reports= spark.read.format("delta").option("header","true").load("Files/Workspace_reports")

Workspace_reports.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspace_reports")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 12, Finished, Available)

# %%
Workspaces= spark.read.format("delta").option("header","true").load("Files/Workspaces")

Workspaces.write.format("delta")\
.option("header","true")\
.mode("overwrite")\
.option("overwriteSchema", "True")\
.saveAsTable("Workspaces")
# Out:
# StatementMeta(, 2b9c7dbf-a11b-4efe-9152-556b6ac40655, 13, Finished, Available)
